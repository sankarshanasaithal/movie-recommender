# %% [markdown]
# ## Import All Packages

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from nltk.stem.porter import PorterStemmer
import pickle
import re

# %% [markdown]
# ## Read the movie dataset

# %%
df = pd.read_csv('movies.csv', encoding='latin-1')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head(10)
# Out:
#                               Name Year of Release                     Genres  \
# 0                       Road House            2024           Action Thriller
# 1                   Dune: Part Two            2024    Action Adventure Drama
# 2  Godzilla x Kong: The New Empire            2024   Action Adventure Sci-Fi
# 3      Ghostbusters: Frozen Empire            2024  Adventure Comedy Fantasy
# 4                      Poor Things            2023      Comedy Drama Romance
# 5                       Road House            1989           Action Thriller
# 6          Beetlejuice Beetlejuice            2024     Comedy Fantasy Horror
# 7                   Dune: Part One            2021    Action Adventure Drama
# 8                           Damsel            2024  Action Adventure Fantasy
# 9                      Oppenheimer            2023   Biography Drama History
#
#    Rating                                         Actors  \
# 0     6.2  JakeGyllenhaal DanielaMelchior ConorMcGregor
# 1     8.8      TimothéeChalamet Zendaya RebeccaFerguson
# 2     6.6        RebeccaHall BrianTyreeHenry DanStevens
# 3     6.5              PaulRudd CarrieCoon FinnWolfhard
# 4     8.0             EmmaStone MarkRuffalo WillemDafoe
# 5     6.7           PatrickSwayze KellyLynch SamElliott
# 6     NaN                                            NaN
# 7     8.0      TimothéeChalamet RebeccaFerguson Zendaya
# 8     6.1    MillieBobbyBrown RayWinstone AngelaBassett
# 9     8.3            CillianMurphy EmilyBlunt MattDamon
#
#                 Director                                        Description  \
# 0              DougLiman  Ex-UFC fighter Dalton takes a job as a bouncer...
# 1        DenisVilleneuve  Paul Atreides unites with Chani and the Fremen...
# 2            AdamWingard  Two ancient titans, Godzilla and Kong, clash i...
# 3               GilKenan  When the discovery of an ancient artifact unle...
# 4        YorgosLanthimos  An account of the fantastical evolution of Bel...
# 5        RowdyHerrington  A bouncer hired to clean up the baddest honkyt...
# 6                    NaN  This is a follow-up to the comedy Beetlejuice ...
# 7        DenisVilleneuve  A noble family becomes embroiled in a war for ...
# 8  JuanCarlosFresnadillo  A dutiful damsel agrees to marry a handsome pr...
# 9       ChristopherNolan  The story of American scientist J. Robert Oppe...
#
#                                                Image
# 0  https://m.media-amazon.com/images/M/MV5BNTFiNT...
# 1  https://m.media-amazon.com/images/M/MV5BN2QyZG...
# 2  https://m.media-amazon.com/images/M/MV5BY2QwOG...
# 3  https://m.media-amazon.com/images/M/MV5BNGE5MW...
# 4  https://m.media-amazon.com/images/M/MV5BNGIyYW...
# 5  https://m.media-amazon.com/images/M/MV5BMTU1MT...
# 6  https://m.media-amazon.com/images/M/MV5BYTk2Yj...
# 7  https://m.media-amazon.com/images/M/MV5BMDQ0Nj...
# 8  https://m.media-amazon.com/images/M/MV5BODRiMT...
# 9  https://m.media-amazon.com/images/M/MV5BMDBmYT...

# %%
df.tail(10)
# Out:
#                                      Name Year of Release  \
# 1040                                   Us            2019
# 1041                    Shaun of the Dead            2004
# 1042                                 Room            2015
# 1043                      Superhero Movie            2008
# 1044                                Speed            1994
# 1045                           Persuasion            2022
# 1046                  The French Dispatch            2021
# 1047              The Rules of Attraction            2002
# 1048  A Beautiful Day in the Neighborhood            2019
# 1049                        Life of Brian            1979
#
#                           Genres  Rating  \
# 1040    Horror Mystery Thriller      6.8
# 1041              Comedy Horror      7.9
# 1042             Drama Thriller      8.1
# 1043       Action Comedy Sci-Fi      4.7
# 1044  Action Adventure Thriller      7.3
# 1045              Drama Romance      5.8
# 1046       Comedy Drama Romance      7.1
# 1047       Comedy Drama Romance      6.6
# 1048            Biography Drama      7.2
# 1049                     Comedy      8.0
#
#                                                Actors         Director  \
# 1040         LupitaNyong'o WinstonDuke ElisabethMoss       JordanPeele
# 1041                SimonPegg NickFrost KateAshfield       EdgarWright
# 1042           BrieLarson JacobTremblay SeanBridgers   LennyAbrahamson
# 1043              DrakeBell LeslieNielsen SaraPaxton        CraigMazin
# 1044          KeanuReeves DennisHopper SandraBullock         JandeBont
# 1045      RichardE.Grant HenryGolding BenBaileySmith   CarrieCracknell
# 1046         BenicioDelToro AdrienBrody TildaSwinton       WesAnderson
# 1047  JamesVanDerBeek IanSomerhalder ShannynSossamon        RogerAvary
# 1048                MatthewRhys TomHanks ChrisCooper    MarielleHeller
# 1049           GrahamChapman JohnCleese MichaelPalin        TerryJones
#
#                                             Description  \
# 1040  Adelaide Wilson and her family are attacked by...
# 1041  The uneventful, aimless lives of a London elec...
# 1042  A little boy is held captive in a room with hi...
# 1043  Orphaned high school student Rick Riker is bit...
# 1044  A young police officer must prevent a bomb exp...
# 1045  Eight years after Anne Elliot was persuaded no...
# 1046  A love letter to journalists set in an outpost...
# 1047  The incredibly spoiled and overprivileged stud...
# 1048  Based on the true story of a real-life friends...
# 1049  Born on the original Christmas in the stable n...
#
#                                                   Image
# 1040  https://m.media-amazon.com/images/M/MV5BZTliNW...
# 1041  https://m.media-amazon.com/images/M/MV5BMTg5Mj...
# 1042  https://m.media-amazon.com/images/M/MV5BMjE4Nz...
# 1043  https://m.media-amazon.com/images/M/MV5BMTc0Nj...
# 1044  https://m.media-amazon.com/images/M/MV5BYjc0Mj...
# 1045  https://m.media-amazon.com/images/M/MV5BZDg3Mz...
# 1046  https://m.media-amazon.com/images/M/MV5BNmQxZT...
# 1047  https://m.media-amazon.com/images/M/MV5BOTc4OT...
# 1048  https://m.media-amazon.com/images/M/MV5BZWE3ZD...
# 1049  https://m.media-amazon.com/images/M/MV5BMDA1ZW...

# %%
df.isna().sum()
# Out:
# Name                0
# Year of Release     0
# Genres              8
# Rating             58
# Actors             58
# Director           58
# Description         2
# Image               4
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Year of Release', 'Genres', 'Rating', 'Actors', 'Director',
#        'Description', 'Image'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             1050 non-null   object
#  1   Year of Release  1050 non-null   object
#  2   Genres           1042 non-null   object
#  3   Rating           992 non-null    float64
#  4   Actors           992 non-null    object
#  5   Director         992 non-null    object
#  6   Description      1048 non-null   object
#  7   Image            1046 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 65.8+ KB

# %% [markdown]
# ## Preprocess and clean the data

# %% [markdown]
# ### 1. Drop all the rows with no values (given as NaN, Na, N/A and so on)

# %%
df = df.dropna(axis=0).reset_index().drop(columns='index')
df
# Out:
#                                     Name Year of Release  \
# 0                             Road House            2024
# 1                         Dune: Part Two            2024
# 2        Godzilla x Kong: The New Empire            2024
# 3            Ghostbusters: Frozen Empire            2024
# 4                            Poor Things            2023
# ..                                   ...             ...
# 985                           Persuasion            2022
# 986                  The French Dispatch            2021
# 987              The Rules of Attraction            2002
# 988  A Beautiful Day in the Neighborhood            2019
# 989                        Life of Brian            1979
#
#                         Genres  Rating  \
# 0             Action Thriller      6.2
# 1      Action Adventure Drama      8.8
# 2     Action Adventure Sci-Fi      6.6
# 3    Adventure Comedy Fantasy      6.5
# 4        Comedy Drama Romance      8.0
# ..                         ...     ...
# 985             Drama Romance      5.8
# 986      Comedy Drama Romance      7.1
# 987      Comedy Drama Romance      6.6
# 988           Biography Drama      7.2
# 989                    Comedy      8.0
#
#                                               Actors         Director  \
# 0      JakeGyllenhaal DanielaMelchior ConorMcGregor         DougLiman
# 1          TimothéeChalamet Zendaya RebeccaFerguson   DenisVilleneuve
# 2            RebeccaHall BrianTyreeHenry DanStevens       AdamWingard
# 3                  PaulRudd CarrieCoon FinnWolfhard          GilKenan
# 4                 EmmaStone MarkRuffalo WillemDafoe   YorgosLanthimos
# ..                                               ...              ...
# 985      RichardE.Grant HenryGolding BenBaileySmith   CarrieCracknell
# 986         BenicioDelToro AdrienBrody TildaSwinton       WesAnderson
# 987  JamesVanDerBeek IanSomerhalder ShannynSossamon        RogerAvary
# 988                MatthewRhys TomHanks ChrisCooper    MarielleHeller
# 989           GrahamChapman JohnCleese MichaelPalin        TerryJones
#
#                                            Description  \
# 0    Ex-UFC fighter Dalton takes a job as a bouncer...
# 1    Paul Atreides unites with Chani and the Fremen...
# 2    Two ancient titans, Godzilla and Kong, clash i...
# 3    When the discovery of an ancient artifact unle...
# 4    An account of the fantastical evolution of Bel...
# ..                                                 ...
# 985  Eight years after Anne Elliot was persuaded no...
# 986  A love letter to journalists set in an outpost...
# 987  The incredibly spoiled and overprivileged stud...
# 988  Based on the true story of a real-life friends...
# 989  Born on the original Christmas in the stable n...
#
#                                                  Image
# 0    https://m.media-amazon.com/images/M/MV5BNTFiNT...
# 1    https://m.media-amazon.com/images/M/MV5BN2QyZG...
# 2    https://m.media-amazon.com/images/M/MV5BY2QwOG...
# 3    https://m.media-amazon.com/images/M/MV5BNGE5MW...
# 4    https://m.media-amazon.com/images/M/MV5BNGIyYW...
# ..                                                 ...
# 985  https://m.media-amazon.com/images/M/MV5BZDg3Mz...
# 986  https://m.media-amazon.com/images/M/MV5BNmQxZT...
# 987  https://m.media-amazon.com/images/M/MV5BOTc4OT...
# 988  https://m.media-amazon.com/images/M/MV5BZWE3ZD...
# 989  https://m.media-amazon.com/images/M/MV5BMDA1ZW...
#
# [990 rows x 8 columns]

# %% [markdown]
# ### 2. Clean the names of actors/directors by replacing non-alphabetic characters with blanks

# %%
def clean_text(text):
    cleaned_text = re.sub(r'[^\w\sÀ-ÿ]', '', str(text)) # removes non-alphabetic characters except accented letters and whitespace
    return cleaned_text

# %%
df['Director'] = df['Director'].apply(clean_text)
df['Actors'] = df['Actors'].apply(clean_text)

# %%
df
# Out:
#                                     Name Year of Release  \
# 0                             Road House            2024
# 1                         Dune: Part Two            2024
# 2        Godzilla x Kong: The New Empire            2024
# 3            Ghostbusters: Frozen Empire            2024
# 4                            Poor Things            2023
# ..                                   ...             ...
# 985                           Persuasion            2022
# 986                  The French Dispatch            2021
# 987              The Rules of Attraction            2002
# 988  A Beautiful Day in the Neighborhood            2019
# 989                        Life of Brian            1979
#
#                         Genres  Rating  \
# 0             Action Thriller      6.2
# 1      Action Adventure Drama      8.8
# 2     Action Adventure Sci-Fi      6.6
# 3    Adventure Comedy Fantasy      6.5
# 4        Comedy Drama Romance      8.0
# ..                         ...     ...
# 985             Drama Romance      5.8
# 986      Comedy Drama Romance      7.1
# 987      Comedy Drama Romance      6.6
# 988           Biography Drama      7.2
# 989                    Comedy      8.0
#
#                                               Actors         Director  \
# 0      JakeGyllenhaal DanielaMelchior ConorMcGregor         DougLiman
# 1          TimothéeChalamet Zendaya RebeccaFerguson   DenisVilleneuve
# 2            RebeccaHall BrianTyreeHenry DanStevens       AdamWingard
# 3                  PaulRudd CarrieCoon FinnWolfhard          GilKenan
# 4                 EmmaStone MarkRuffalo WillemDafoe   YorgosLanthimos
# ..                                               ...              ...
# 985       RichardEGrant HenryGolding BenBaileySmith   CarrieCracknell
# 986         BenicioDelToro AdrienBrody TildaSwinton       WesAnderson
# 987  JamesVanDerBeek IanSomerhalder ShannynSossamon        RogerAvary
# 988                MatthewRhys TomHanks ChrisCooper    MarielleHeller
# 989           GrahamChapman JohnCleese MichaelPalin        TerryJones
#
#                                            Description  \
# 0    Ex-UFC fighter Dalton takes a job as a bouncer...
# 1    Paul Atreides unites with Chani and the Fremen...
# 2    Two ancient titans, Godzilla and Kong, clash i...
# 3    When the discovery of an ancient artifact unle...
# 4    An account of the fantastical evolution of Bel...
# ..                                                 ...
# 985  Eight years after Anne Elliot was persuaded no...
# 986  A love letter to journalists set in an outpost...
# 987  The incredibly spoiled and overprivileged stud...
# 988  Based on the true story of a real-life friends...
# 989  Born on the original Christmas in the stable n...
#
#                                                  Image
# 0    https://m.media-amazon.com/images/M/MV5BNTFiNT...
# 1    https://m.media-amazon.com/images/M/MV5BN2QyZG...
# 2    https://m.media-amazon.com/images/M/MV5BY2QwOG...
# 3    https://m.media-amazon.com/images/M/MV5BNGE5MW...
# 4    https://m.media-amazon.com/images/M/MV5BNGIyYW...
# ..                                                 ...
# 985  https://m.media-amazon.com/images/M/MV5BZDg3Mz...
# 986  https://m.media-amazon.com/images/M/MV5BNmQxZT...
# 987  https://m.media-amazon.com/images/M/MV5BOTc4OT...
# 988  https://m.media-amazon.com/images/M/MV5BZWE3ZD...
# 989  https://m.media-amazon.com/images/M/MV5BMDA1ZW...
#
# [990 rows x 8 columns]

# %% [markdown]
# ### 3. Merge the essential columns

# %%
df['features'] =  df['Description'] + ' ' + df['Genres'] + df['Actors'] + df['Director']

# %%
df['features']
# Out:
# 0      Ex-UFC fighter Dalton takes a job as a bouncer...
# 1      Paul Atreides unites with Chani and the Fremen...
# 2      Two ancient titans, Godzilla and Kong, clash i...
# 3      When the discovery of an ancient artifact unle...
# 4      An account of the fantastical evolution of Bel...
#                              ...
# 985    Eight years after Anne Elliot was persuaded no...
# 986    A love letter to journalists set in an outpost...
# 987    The incredibly spoiled and overprivileged stud...
# 988    Based on the true story of a real-life friends...
# 989    Born on the original Christmas in the stable n...
# Name: features, Length: 990, dtype: object

# %% [markdown]
# ### 4. Convert the features to lower case for best results

# %%
df['features'] = df['features'].apply(lambda x: x.lower())
df['features'][0]
# Out:
# 'ex-ufc fighter dalton takes a job as a bouncer at a florida keys roadhouse, only to discover that this paradise is not all it seems. action thriller jakegyllenhaal danielamelchior conormcgregor dougliman'

# %% [markdown]
# ### 5. Apply stemming modules to normalize each feature

# %%
ps = PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
df['features'] = df['features'].apply(stem)

# %%
df['features'][0]
# Out:
# 'ex-ufc fighter dalton take a job as a bouncer at a florida key roadhouse, onli to discov that thi paradis is not all it seems. action thriller jakegyllenha danielamelchior conormcgregor dougliman'

# %% [markdown]
# ## Build a recommender model using vectorization techniques

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['features'])

# %%
# Calculate cosine similarity between TF-IDF vectors
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# ## Recommend 10 movies similar to the given movie

# %%
def recommendations(movie_name, n=10):
    movie_idx = df.index[df['Name'] == movie_name].tolist()
    if not movie_idx:
        print("Movie not found!")
        return None
    movie_idx = movie_idx[0]
    sim_scores = list(enumerate(cosine_sim[movie_idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:n+1]  # Do not include the movie itself (sim_scores[0])
    recommended_movies = [df.iloc[i[0]]['Name'] for i in sim_scores]
    return recommended_movies

# %%
movie_name = 'John Wick'  # Specify the movie name for which you want recommendations
top_recommendations = recommendations(movie_name)
if top_recommendations:
    for x in top_recommendations:
        print(x)
# Out:
# John Wick: Chapter 3 - Parabellum
# John Wick: Chapter 2
# Skyfall
# The Fall Guy
# Deadpool
# Zodiac
# John Wick: Chapter 4
# Snatch
# Taken
# Mission: Impossible - Dead Reckoning Part One

# %% [markdown]
# ## Convert the model and the dataset into pickle file format for use in front-end

# %%
dataset = df.to_dict('records')

# %%
pickle.dump(dataset,open('movie_list.pkl','wb'))
pickle.dump(cosine_sim,open('similarity.pkl','wb'))
